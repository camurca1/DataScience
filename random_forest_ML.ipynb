# %% [markdown]
# ## Pacotes necessários
#
# pickle <br>
# sklearn <br>
# yellowbrick <br>

# %%
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# ## Carregar Dados Salvos - Base Crédito
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/credit.pkl', 'rb') as f:
    X_credit_train, X_credit_test, Y_credit_train, Y_credit_test = pickle.load(f)

X_credit_train.shape, X_credit_test.shape, Y_credit_train.shape, Y_credit_test.shape
# Out:
# ((1500, 3), (500, 3), (1500,), (500,))

# %% [markdown]
# ## Treinamento algoritmo Random Forest - Base Crédito

# %%
forest_credit_data = RandomForestClassifier(n_estimators=80, criterion='entropy', random_state=0)
forest_credit_data.fit(X_credit_train, Y_credit_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=80, random_state=0)

# %% [markdown]
# ## Previsões algoritmo Random Forest - Base Crédito

# %%
predict_credit = forest_credit_data.predict(X_credit_test)

# %% [markdown]
# ## Estatísticas de acerto - Base Crédito - 98,40%
#
# Acurácia:

# %%
cm = ConfusionMatrix(forest_credit_data)
cm.fit(X_credit_train, Y_credit_train)
cm.score(X_credit_test, Y_credit_test)
# Out:
# 0.984

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_credit_test, predict_credit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       436
#            1       0.95      0.92      0.94        64
#
#     accuracy                           0.98       500
#    macro avg       0.97      0.96      0.96       500
# weighted avg       0.98      0.98      0.98       500

# %% [markdown]
# ## Carregar Dados Salvos - Base Census
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/census.pkl', 'rb') as f:
    X_census_train, X_census_test, Y_census_train, Y_census_test = pickle.load(f)

X_census_train.shape, X_census_test.shape, Y_census_train.shape, Y_census_test.shape
# Out:
# ((27676, 108), (4885, 108), (27676,), (4885,))

# %% [markdown]
# ## Treinamento algoritmo Random Forest - Base Census

# %%
forest_census_data = RandomForestClassifier(n_estimators=110, criterion='entropy', random_state=0)
forest_census_data.fit(X_census_train, Y_census_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=110, random_state=0)

# %% [markdown]
# ## Previsões algoritmo Random Forest - Base census

# %%
predict_census = forest_census_data.predict(X_census_test)

# %% [markdown]
# ## Estatísticas de acerto - Base census - 85,15%
#
# Acurácia:

# %%
cm = ConfusionMatrix(forest_census_data)
cm.fit(X_census_train, Y_census_train)
cm.score(X_census_test, Y_census_test)
# Out:
# 0.8515864892528148

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_census_test, predict_census))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.93      0.90      3693
#         >50K       0.73      0.61      0.67      1192
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.77      0.79      4885
# weighted avg       0.85      0.85      0.85      4885
