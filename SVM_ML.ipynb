# %% [markdown]
# ## Pacotes necessários
#
# pickle <br>
# sklearn <br>
# yellowbrick <br>

# %%
import pickle
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# ## Carregar Dados Salvos - Base Crédito
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/credit.pkl', 'rb') as f:
    X_credit_train, X_credit_test, Y_credit_train, Y_credit_test = pickle.load(f)

X_credit_train.shape, X_credit_test.shape, Y_credit_train.shape, Y_credit_test.shape
# Out:
# ((1500, 3), (500, 3), (1500,), (500,))

# %% [markdown]
# ## Treinamento algoritmo svm Classifier - Base Crédito

# %%
svm_credit_data = SVC(kernel='rbf', random_state=1, C=2.0)
svm_credit_data.fit(X_credit_train, Y_credit_train)
# Out:
# SVC(C=2.0, random_state=1)

# %% [markdown]
# ## Previsões algoritmo svm Classifier - Base Crédito

# %%
predict_credit = svm_credit_data.predict(X_credit_test)

# %% [markdown]
# ## Estatísticas de acerto - Base Crédito - 98.8%
#
# Acurácia:

# %%
cm = ConfusionMatrix(svm_credit_data)
cm.fit(X_credit_train, Y_credit_train)
cm.score(X_credit_test, Y_credit_test)
# Out:
# 0.988

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_credit_test, predict_credit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       436
#            1       0.97      0.94      0.95        64
#
#     accuracy                           0.99       500
#    macro avg       0.98      0.97      0.97       500
# weighted avg       0.99      0.99      0.99       500

# %% [markdown]
# ## Carregar Dados Salvos - Base Census
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/census.pkl', 'rb') as f:
    X_census_train, X_census_test, Y_census_train, Y_census_test = pickle.load(f)

X_census_train.shape, X_census_test.shape, Y_census_train.shape, Y_census_test.shape
# Out:
# ((27676, 108), (4885, 108), (27676,), (4885,))

# %% [markdown]
# ## Treinamento algoritmo svm Classifier - Base Census

# %%
svm_census_data = SVC(kernel='rbf', random_state=1, C=1.0)
svm_census_data.fit(X_census_train, Y_census_train)
# Out:
# SVC(random_state=1)

# %% [markdown]
# ## Previsões algoritmo svm Classifier - Base census

# %%
predict_census = svm_census_data.predict(X_census_test)

# %% [markdown]
# ## Estatísticas de acerto - Base census - 84.93%
#
# Acurácia:

# %%
cm = ConfusionMatrix(svm_census_data)
cm.fit(X_census_train, Y_census_train)
cm.score(X_census_test, Y_census_test)
# Out:
# 0.8493346980552713

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_census_test, predict_census))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.87      0.94      0.90      3693
#         >50K       0.75      0.57      0.65      1192
#
#     accuracy                           0.85      4885
#    macro avg       0.81      0.75      0.78      4885
# weighted avg       0.84      0.85      0.84      4885
