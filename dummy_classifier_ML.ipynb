# %% [markdown]
# ## Pacotes necessários
#
# pickle <br>
# sklearn <br>
# yellowbrick <br>

# %%
import pickle
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# ## Carregar Dados Salvos - Base Crédito
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/credit.pkl', 'rb') as f:
    X_credit_train, X_credit_test, Y_credit_train, Y_credit_test = pickle.load(f)

X_credit_train.shape, X_credit_test.shape, Y_credit_train.shape, Y_credit_test.shape
# Out:
# ((1500, 3), (500, 3), (1500,), (500,))

# %% [markdown]
# ## Treinamento algoritmo Dummy Classifier - Base Crédito

# %%
dummy_credit_data = DummyClassifier('most_frequent', random_state=0)
dummy_credit_data.fit(X_credit_train, Y_credit_train)
# Out:
# C:\Users\alexa\PycharmProjects\DataScience\venv\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass strategy=most_frequent as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# DummyClassifier(random_state=0, strategy='most_frequent')

# %% [markdown]
# ## Previsões algoritmo Dummy Classifier - Base Crédito

# %%
predict_credit = dummy_credit_data.predict(X_credit_test)

# %% [markdown]
# ## Estatísticas de acerto - Base Crédito - 87,2%
#
# Acurácia:

# %%
cm = ConfusionMatrix(dummy_credit_data)
cm.fit(X_credit_train, Y_credit_train)
cm.score(X_credit_test, Y_credit_test)
# Out:
# 0.872

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_credit_test, predict_credit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       436
#            1       0.00      0.00      0.00        64
#
#     accuracy                           0.87       500
#    macro avg       0.44      0.50      0.47       500
# weighted avg       0.76      0.87      0.81       500
# C:\Users\alexa\PycharmProjects\DataScience\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\alexa\PycharmProjects\DataScience\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Carregar Dados Salvos - Base Census
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/census.pkl', 'rb') as f:
    X_census_train, X_census_test, Y_census_train, Y_census_test = pickle.load(f)

X_census_train.shape, X_census_test.shape, Y_census_train.shape, Y_census_test.shape
# Out:
# ((27676, 108), (4885, 108), (27676,), (4885,))

# %% [markdown]
# ## Treinamento algoritmo Dummy Classifier - Base Census

# %%
dummy_census_data = DummyClassifier('most_frequent', random_state=0)
dummy_census_data.fit(X_census_train, Y_census_train)
# Out:
# C:\Users\alexa\PycharmProjects\DataScience\venv\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass strategy=most_frequent as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# DummyClassifier(random_state=0, strategy='most_frequent')

# %% [markdown]
# ## Previsões algoritmo Dummy Classifier - Base census

# %%
predict_census = dummy_census_data.predict(X_census_test)

# %% [markdown]
# ## Estatísticas de acerto - Base census - 75,5%
#
# Acurácia:

# %%
cm = ConfusionMatrix(dummy_census_data)
cm.fit(X_census_train, Y_census_train)
cm.score(X_census_test, Y_census_test)
# Out:
# 0.7559877175025589

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_census_test, predict_census))
# Out:
# C:\Users\alexa\PycharmProjects\DataScience\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        <=50K       0.76      1.00      0.86      3693
#         >50K       0.00      0.00      0.00      1192
#
#     accuracy                           0.76      4885
#    macro avg       0.38      0.50      0.43      4885
# weighted avg       0.57      0.76      0.65      4885
# C:\Users\alexa\PycharmProjects\DataScience\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
