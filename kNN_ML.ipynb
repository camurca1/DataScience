# %% [markdown]
# ## Pacotes necessários
#
# pickle <br>
# sklearn <br>
# yellowbrick <br>

# %%
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# ## Carregar Dados Salvos - Base Crédito
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/credit.pkl', 'rb') as f:
    X_credit_train, X_credit_test, Y_credit_train, Y_credit_test = pickle.load(f)

X_credit_train.shape, X_credit_test.shape, Y_credit_train.shape, Y_credit_test.shape
# Out:
# ((1500, 3), (500, 3), (1500,), (500,))

# %% [markdown]
# ## Treinamento algoritmo knn Classifier - Base Crédito

# %%
knn_credit_data = KNeighborsClassifier(n_neighbors=5)
knn_credit_data.fit(X_credit_train, Y_credit_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Previsões algoritmo knn Classifier - Base Crédito

# %%
predict_credit = knn_credit_data.predict(X_credit_test)

# %% [markdown]
# ## Estatísticas de acerto - Base Crédito - 98.6%
#
# Acurácia:

# %%
cm = ConfusionMatrix(knn_credit_data)
cm.fit(X_credit_train, Y_credit_train)
cm.score(X_credit_test, Y_credit_test)
# Out:
# 0.986

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_credit_test, predict_credit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       436
#            1       0.94      0.95      0.95        64
#
#     accuracy                           0.99       500
#    macro avg       0.97      0.97      0.97       500
# weighted avg       0.99      0.99      0.99       500

# %% [markdown]
# ## Carregar Dados Salvos - Base Census
#
# X_treinamento, X_teste, Y_treinamento, Y_teste:

# %%
with open('content/census.pkl', 'rb') as f:
    X_census_train, X_census_test, Y_census_train, Y_census_test = pickle.load(f)

X_census_train.shape, X_census_test.shape, Y_census_train.shape, Y_census_test.shape
# Out:
# ((27676, 108), (4885, 108), (27676,), (4885,))

# %% [markdown]
# ## Treinamento algoritmo knn Classifier - Base Census

# %%
knn_census_data = KNeighborsClassifier(n_neighbors=20)
knn_census_data.fit(X_census_train, Y_census_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %% [markdown]
# ## Previsões algoritmo knn Classifier - Base census

# %%
predict_census = knn_census_data.predict(X_census_test)

# %% [markdown]
# ## Estatísticas de acerto - Base census - 82,98%
#
# Acurácia:

# %%
cm = ConfusionMatrix(knn_census_data)
cm.fit(X_census_train, Y_census_train)
cm.score(X_census_test, Y_census_test)
# Out:
# 0.8298874104401228

# %% [markdown]
# Relatório de Classificação:

# %%
print(classification_report(Y_census_test, predict_census))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.93      0.89      3693
#         >50K       0.70      0.52      0.60      1192
#
#     accuracy                           0.83      4885
#    macro avg       0.78      0.73      0.75      4885
# weighted avg       0.82      0.83      0.82      4885
